# %% [markdown]
# ## Entendimiento del problema
#
# ### By:
# Maria Camila Sepulveda Torres
#
# ### Date:
# 2026-08-15
#
# ### Description:
#
# Descargar los datos y entender el problema a realizar, contestar en el cuaderno
#
# ¿Cual es el objetivo del problema?
# ¿Cómo se usará su solución?
# ¿Cuáles son las soluciones actuales (si las hay)?
# ¿Cómo se debe marcar este problema (supervisado / no supervisado, en línea / fuera de línea, etc.)
# ¿Cómo se debe medir el desempeño o el rendimiento de la solución, una primera intuición?
# ¿La medida de desempeño está alineada con el objetivo del problema?
# ¿Cuál sería el desempeño o rendimiento mínimo necesario para alcanzar el objetivo del problema?
# ¿Cuáles son los problemas parecidos? ¿Se puede reutilizar experiencias o herramientas ya creadas?
# ¿Hay experiencia del problema disponible?
# (Importante) ¿Cómo se puede resolver el problema manualmente?
# Hacer un listado de los supuestos que hay hasta este momento.
# ¿Cuál es la fuente de los datos?
# Como se actualizan los datos?
# Cada cuanto tiempo se actualizan los datos

# %% [markdown]
# ## ¿Cual es el objetivo del problema?🧐🧐🧐
# El objetivo es mirar la posibilidad de ser admitidos  en una universidad tomando en cuenta

# %% [markdown]
# ## ¿Cómo se usará su solución?📚📚
# Sera una herramienta que apoyara a os estudiantes a seleccionar una posible universidad

# %% [markdown]
# ## ¿Cuáles son las soluciones actuales (si las hay)?👊🏻👊🏻
# Comparacion de los resultados y verificacion de los requisitos por universidad

# %% [markdown]
# ## ¿Cómo se debe marcar este problema (supervisado / no supervisado, en línea / fuera de línea, etc.)👀👀
# Es un problema de **aprendizaje supervisado de regresión**,se busca predecir Chance of Admit. Además, es fuera de línea , el modelo se entrenará con un conjunto de datos previamente recopilado.

# %% [markdown]
# ## ¿Cómo se debe medir el desempeño o el rendimiento de la solución, una primera intuición?🧮🧮
# Se podria hacer con MAE para ver cque tan lejos esta mi modelo de lo real

# %% [markdown]
# ## ¿La medida de desempeño está alineada con el objetivo del problema?🎯🎯
# Si, este me permite comparar lo que me dio mi modelo con lo real

# %% [markdown]
# ## ¿Cuál sería el desempeño o rendimiento mínimo necesario para alcanzar el objetivo del problema?🧐🎯
# Se ebe construir un modelo base y mirar si es posile e ir mejorando

# %% [markdown]
# ## ¿Cuáles son los problemas parecidos? ¿Se puede reutilizar experiencias o herramientas ya creadas?
# Problemas de predicción de admisión universitaria, rendimiento académico y ganar o perder el año. Se pueden reutilizar técnicas de regresión y herramientas de aprendizaje automático.

# %% [markdown]
# ## ¿Hay experiencia del problema disponible?
# Sí. Existen aplicaciones de técnicas estadísticas y de aprendizaje automático para predecir resultados académicos y procesos de admisión.

# %% [markdown]
# ## (Importante) ¿Cómo se puede resolver el problema manualmente?🖐🏻🖐🏻
# Comparando las características de un estudiante con estudiantes de perfiles similares y observando sus probabilidades de admisión.

# %% [markdown]
# ## Hacer un listado de los supuestos que hay hasta este momento.📋📋
# La variables tienen gran relacion con la de salida
# La predicción representa una estimación y no garantiza la admisión.
