# %% [markdown]
# ## Feature Engineering
#
# ### By:
# Maria Camila Sepulveda Torres
#
# ### Date:
# 2024-08-21
#
# ### Description:
#
# En este notebook se realiza el proceso de Feature Engineering del conjunto de datos de admisiones, tomando como base los resultados obtenidos durante el análisis exploratorio de datos.
#
# El proceso incluye la limpieza de los datos, selección de atributos, tratamiento de valores faltantes, transformación y codificación de variables, escalado de atributos y construcción de los pipelines de preprocesamiento mediante transformadores de `scikit-learn`.
#
# El objetivo es obtener un conjunto de datos preparado para ser utilizado posteriormente en el entrenamiento de modelos de machine learning para estimar `Chance of Admit`.

# %% [markdown]
# ## 📚 Import  libraries

# %%
from pathlib import Path

import pandas as pd
import sklearn as sk

# %% [markdown]
# ## 💾 Load data

# %%
# ruta del directorio de datos
DATA_DIR = Path.cwd().resolve().parents[1] / "data"

admission_df = pd.read_parquet(
    DATA_DIR / "02_intermediate/admission_type_fixed.parquet",
    engine="pyarrow",
)

# %%
print("Versión de Pandas: ", pd.__version__)
print("Versión de sklearn: ", sk.__version__)

# %% [markdown]
# ## 👷 Data preparation or Feature Engineering

# %% [markdown]
# ## 📊 Analysis of Results and Conclusions
#
# Description of the results obtained and if there are conclusions that can be drawn from them.
#
# The analysis of results must be related to the description of the task.
#
# **Note:** An analysis of results does not necessarily lead to conclusions, but to ideas or proposals for future work

# %% [markdown]
# ## 💡 Proposals and Ideas
#
# From the results obtained, what ideas or proposals can be generated to continue with the project

# %% [markdown]
# ## 📖 References
